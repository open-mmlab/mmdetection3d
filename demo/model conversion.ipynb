# %%
from mmdet3d.apis import init_model, inference_detector, show_result_meshlab

config_file = '../configs/centerpoint/centerpoint_03pillar_kitti_lum.py'
checkpoint_file = '/home/mark/checkpoints/centrpoint/centerpoint_lum_iris.pth'

# build the model from a config file and a checkpoint file
model = init_model(config_file, checkpoint_file, device='cuda:0')
print(model)
# Out:
# load checkpoint from local path: /home/mark/checkpoints/centrpoint/centerpoint_lum_iris.pth
# CenterPoint(
#   (pts_voxel_layer): Voxelization(voxel_size=[0.2, 0.2, 16], point_cloud_range=[0, -55.2, -15, 128, 55.2, 15], max_num_points=20, max_voxels=(30000, 40000), deterministic=True)
#   (pts_voxel_encoder): PillarFeatureNet(
#     (pfn_layers): ModuleList(
#       (0): PFNLayer(
#         (norm): BatchNorm1d(64, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (linear): Linear(in_features=10, out_features=64, bias=False)
#       )
#     )
#   )
#   (pts_middle_encoder): PointPillarsScatter()
#   (pts_backbone): SECOND(
#     (blocks): ModuleList(
#       (0): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(64, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#         (6): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (7): BatchNorm2d(64, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (8): ReLU(inplace=True)
#         (9): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (10): BatchNorm2d(64, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (11): ReLU(inplace=True)
#       )
#       (1): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(128, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(128, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#         (6): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (7): BatchNorm2d(128, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (8): ReLU(inplace=True)
#         (9): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (10): BatchNorm2d(128, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (11): ReLU(inplace=True)
#         (12): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (13): BatchNorm2d(128, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (14): ReLU(inplace=True)
#         (15): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (16): BatchNorm2d(128, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (17): ReLU(inplace=True)
#       )
#       (2): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#         (6): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (7): BatchNorm2d(256, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (8): ReLU(inplace=True)
#         (9): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (10): BatchNorm2d(256, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (11): ReLU(inplace=True)
#         (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (13): BatchNorm2d(256, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (14): ReLU(inplace=True)
#         (15): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (16): BatchNorm2d(256, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (17): ReLU(inplace=True)
#       )
#     )
#   )
#   init_cfg={'type': 'Kaiming', 'layer': 'Conv2d'}
#   (pts_neck): SECONDFPN(
#     (deblocks): ModuleList(
#       (0): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(2, 2), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#       (1): Sequential(
#         (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(128, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#       (2): Sequential(
#         (0): ConvTranspose2d(256, 128, kernel_size=(2, 2), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#     )
#   )
#   init_cfg=[{'type': 'Kaiming', 'layer': 'ConvTranspose2d'}, {'type': 'Constant', 'layer': 'NaiveSyncBatchNorm2d', 'val': 1.0}]
#   (pts_bbox_head): CenterHead(
#     (loss_cls): GaussianFocalLoss()
#     (loss_bbox): L1Loss()
#     (shared_conv): ConvModule(
#       (conv): Conv2d(384, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activate): ReLU(inplace=True)
#     )
#     (task_heads): ModuleList(
#       (0): SeparateHead(
#         (reg): Sequential(
#           (0): ConvModule(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (activate): ReLU(inplace=True)
#           )
#           (1): Conv2d(64, 2, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (height): Sequential(
#           (0): ConvModule(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (activate): ReLU(inplace=True)
#           )
#           (1): Conv2d(64, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (dim): Sequential(
#           (0): ConvModule(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (activate): ReLU(inplace=True)
#           )
#           (1): Conv2d(64, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (rot): Sequential(
#           (0): ConvModule(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (activate): ReLU(inplace=True)
#           )
#           (1): Conv2d(64, 2, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (heatmap): Sequential(
#           (0): ConvModule(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (activate): ReLU(inplace=True)
#           )
#           (1): Conv2d(64, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       init_cfg={'type': 'Kaiming', 'layer': 'Conv2d'}
#       (1): SeparateHead(
#         (reg): Sequential(
#           (0): ConvModule(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (activate): ReLU(inplace=True)
#           )
#           (1): Conv2d(64, 2, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (height): Sequential(
#           (0): ConvModule(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (activate): ReLU(inplace=True)
#           )
#           (1): Conv2d(64, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (dim): Sequential(
#           (0): ConvModule(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (activate): ReLU(inplace=True)
#           )
#           (1): Conv2d(64, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (rot): Sequential(
#           (0): ConvModule(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (activate): ReLU(inplace=True)
#           )
#           (1): Conv2d(64, 2, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (heatmap): Sequential(
#           (0): ConvModule(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (activate): ReLU(inplace=True)
#           )
#           (1): Conv2d(64, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       init_cfg={'type': 'Kaiming', 'layer': 'Conv2d'}
#       (2): SeparateHead(
#         (reg): Sequential(
#           (0): ConvModule(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (activate): ReLU(inplace=True)
#           )
#           (1): Conv2d(64, 2, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (height): Sequential(
#           (0): ConvModule(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (activate): ReLU(inplace=True)
#           )
#           (1): Conv2d(64, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (dim): Sequential(
#           (0): ConvModule(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (activate): ReLU(inplace=True)
#           )
#           (1): Conv2d(64, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (rot): Sequential(
#           (0): ConvModule(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (activate): ReLU(inplace=True)
#           )
#           (1): Conv2d(64, 2, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (heatmap): Sequential(
#           (0): ConvModule(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (activate): ReLU(inplace=True)
#           )
#           (1): Conv2d(64, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       init_cfg={'type': 'Kaiming', 'layer': 'Conv2d'}
#       (3): SeparateHead(
#         (reg): Sequential(
#           (0): ConvModule(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (activate): ReLU(inplace=True)
#           )
#           (1): Conv2d(64, 2, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (height): Sequential(
#           (0): ConvModule(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (activate): ReLU(inplace=True)
#           )
#           (1): Conv2d(64, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (dim): Sequential(
#           (0): ConvModule(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (activate): ReLU(inplace=True)
#           )
#           (1): Conv2d(64, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (rot): Sequential(
#           (0): ConvModule(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (activate): ReLU(inplace=True)
#           )
#           (1): Conv2d(64, 2, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (heatmap): Sequential(
#           (0): ConvModule(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (activate): ReLU(inplace=True)
#           )
#           (1): Conv2d(64, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       init_cfg={'type': 'Kaiming', 'layer': 'Conv2d'}
#     )
#   )
# )

# %%
# test a single sample
pcd = '/home/mark/KITTI/testing/velodyne/000008.bin'
result, data = inference_detector(model, pcd)
# Out:
# ['flip', 'pcd_horizontal_flip', 'pcd_vertical_flip', 'box_mode_3d', 'box_type_3d', 'pcd_trans', 'pcd_scale_factor', 'pcd_rotation', 'pcd_rotation_angle', 'pts_filename', 'transformation_3d_flow'] torch.Size([61241, 4])
# True

# %%
import torch

pc = torch.randn([10000, 4]).cuda()
voxels, num_points, coors = model.voxelize([pc])
print('pts_voxel_layer: ', voxels.shape, num_points.shape, coors.shape,)

voxel_features = model.pts_voxel_encoder(voxels, num_points, coors)
print('pts_voxel_encoder: ', voxel_features.shape)

x = model.pts_middle_encoder(voxel_features, coors)
print('pts_middle_encoder: ', x.shape)

x = model.pts_backbone(x)
print('pts_backbone: ', x[0].shape, x[1].shape, x[2].shape)

x = model.pts_neck(x)
print('pts_neck: ', x[0].shape)

out = model.pts_bbox_head(x)
print('pts_bbox_head:')

class_names=['Car', 'Pedestrian', 'Cyclist', 'Large_vehicle']
for i, val in enumerate(out):
    print(f'{class_names[i]}:')
    for k, v in out[i][0].items():
        print(f'   {k}: {v.shape}')
# Out:
# pts_voxel_layer:  torch.Size([601, 20, 4]) torch.Size([601]) torch.Size([601, 4])
# pts_voxel_encoder:  torch.Size([601, 64])
# pts_middle_encoder:  torch.Size([1, 64, 552, 640])
# pts_backbone:  torch.Size([1, 64, 276, 320]) torch.Size([1, 128, 138, 160]) torch.Size([1, 256, 69, 80])
# pts_neck:  torch.Size([1, 384, 138, 160])
# pts_bbox_head:
# Car:
#    reg: torch.Size([1, 2, 138, 160])
#    height: torch.Size([1, 1, 138, 160])
#    dim: torch.Size([1, 3, 138, 160])
#    rot: torch.Size([1, 2, 138, 160])
#    heatmap: torch.Size([1, 1, 138, 160])
# Pedestrian:
#    reg: torch.Size([1, 2, 138, 160])
#    height: torch.Size([1, 1, 138, 160])
#    dim: torch.Size([1, 3, 138, 160])
#    rot: torch.Size([1, 2, 138, 160])
#    heatmap: torch.Size([1, 1, 138, 160])
# Cyclist:
#    reg: torch.Size([1, 2, 138, 160])
#    height: torch.Size([1, 1, 138, 160])
#    dim: torch.Size([1, 3, 138, 160])
#    rot: torch.Size([1, 2, 138, 160])
#    heatmap: torch.Size([1, 1, 138, 160])
# Large_vehicle:
#    reg: torch.Size([1, 2, 138, 160])
#    height: torch.Size([1, 1, 138, 160])
#    dim: torch.Size([1, 3, 138, 160])
#    rot: torch.Size([1, 2, 138, 160])
#    heatmap: torch.Size([1, 1, 138, 160])

# %%
sub_model = model.get_sub_model_for_conversion()
out = sub_model(voxels, num_points, coors)
for i, val in enumerate(out):
    print(f'{class_names[i]}:')
    for k, v in out[i][0].items():
        print(f'   {k}: {v.shape}')
print(sub_model)
# Out:
# SubModel(
#   (pts_voxel_encoder): PillarFeatureNet(
#     (pfn_layers): ModuleList(
#       (0): PFNLayer(
#         (norm): BatchNorm1d(64, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (linear): Linear(in_features=10, out_features=64, bias=False)
#       )
#     )
#   )
#   (pts_middle_encoder): PointPillarsScatter()
#   (pts_backbone): SECOND(
#     (blocks): ModuleList(
#       (0): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(64, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#         (6): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (7): BatchNorm2d(64, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (8): ReLU(inplace=True)
#         (9): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (10): BatchNorm2d(64, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (11): ReLU(inplace=True)
#       )
#       (1): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(128, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(128, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#         (6): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (7): BatchNorm2d(128, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (8): ReLU(inplace=True)
#         (9): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (10): BatchNorm2d(128, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (11): ReLU(inplace=True)
#         (12): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (13): BatchNorm2d(128, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (14): ReLU(inplace=True)
#         (15): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (16): BatchNorm2d(128, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (17): ReLU(inplace=True)
#       )
#       (2): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#         (6): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (7): BatchNorm2d(256, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (8): ReLU(inplace=True)
#         (9): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (10): BatchNorm2d(256, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (11): ReLU(inplace=True)
#         (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (13): BatchNorm2d(256, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (14): ReLU(inplace=True)
#         (15): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (16): BatchNorm2d(256, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (17): ReLU(inplace=True)
#       )
#     )
#   )
#   init_cfg={'type': 'Kaiming', 'layer': 'Conv2d'}
#   (pts_neck): SECONDFPN(
#     (deblocks): ModuleList(
#       (0): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(2, 2), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#       (1): Sequential(
#         (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(128, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#       (2): Sequential(
#         (0): ConvTranspose2d(256, 128, kernel_size=(2, 2), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#     )
#   )
#   init_cfg=[{'type': 'Kaiming', 'layer': 'ConvTranspose2d'}, {'type': 'Constant', 'layer': 'NaiveSyncBatchNorm2d', 'val': 1.0}]
#   (pts_bbox_head): CenterHead(
#     (loss_cls): GaussianFocalLoss()
#     (loss_bbox): L1Loss()
#     (shared_conv): ConvModule(
#       (conv): Conv2d(384, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activate): ReLU(inplace=True)
#     )
#     (task_heads): ModuleList(
#       (0): SeparateHead(
#         (reg): Sequential(
#           (0): ConvModule(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (activate): ReLU(inplace=True)
#           )
#           (1): Conv2d(64, 2, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (height): Sequential(
#           (0): ConvModule(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (activate): ReLU(inplace=True)
#           )
#           (1): Conv2d(64, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (dim): Sequential(
#           (0): ConvModule(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (activate): ReLU(inplace=True)
#           )
#           (1): Conv2d(64, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (rot): Sequential(
#           (0): ConvModule(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (activate): ReLU(inplace=True)
#           )
#           (1): Conv2d(64, 2, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (heatmap): Sequential(
#           (0): ConvModule(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (activate): ReLU(inplace=True)
#           )
#           (1): Conv2d(64, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       init_cfg={'type': 'Kaiming', 'layer': 'Conv2d'}
#       (1): SeparateHead(
#         (reg): Sequential(
#           (0): ConvModule(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (activate): ReLU(inplace=True)
#           )
#           (1): Conv2d(64, 2, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (height): Sequential(
#           (0): ConvModule(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (activate): ReLU(inplace=True)
#           )
#           (1): Conv2d(64, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (dim): Sequential(
#           (0): ConvModule(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (activate): ReLU(inplace=True)
#           )
#           (1): Conv2d(64, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (rot): Sequential(
#           (0): ConvModule(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (activate): ReLU(inplace=True)
#           )
#           (1): Conv2d(64, 2, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (heatmap): Sequential(
#           (0): ConvModule(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (activate): ReLU(inplace=True)
#           )
#           (1): Conv2d(64, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       init_cfg={'type': 'Kaiming', 'layer': 'Conv2d'}
#       (2): SeparateHead(
#         (reg): Sequential(
#           (0): ConvModule(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (activate): ReLU(inplace=True)
#           )
#           (1): Conv2d(64, 2, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (height): Sequential(
#           (0): ConvModule(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (activate): ReLU(inplace=True)
#           )
#           (1): Conv2d(64, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (dim): Sequential(
#           (0): ConvModule(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (activate): ReLU(inplace=True)
#           )
#           (1): Conv2d(64, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (rot): Sequential(
#           (0): ConvModule(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (activate): ReLU(inplace=True)
#           )
#           (1): Conv2d(64, 2, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (heatmap): Sequential(
#           (0): ConvModule(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (activate): ReLU(inplace=True)
#           )
#           (1): Conv2d(64, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       init_cfg={'type': 'Kaiming', 'layer': 'Conv2d'}
#       (3): SeparateHead(
#         (reg): Sequential(
#           (0): ConvModule(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (activate): ReLU(inplace=True)
#           )
#           (1): Conv2d(64, 2, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (height): Sequential(
#           (0): ConvModule(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (activate): ReLU(inplace=True)
#           )
#           (1): Conv2d(64, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (dim): Sequential(
#           (0): ConvModule(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (activate): ReLU(inplace=True)
#           )
#           (1): Conv2d(64, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (rot): Sequential(
#           (0): ConvModule(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (activate): ReLU(inplace=True)
#           )
#           (1): Conv2d(64, 2, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (heatmap): Sequential(
#           (0): ConvModule(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (activate): ReLU(inplace=True)
#           )
#           (1): Conv2d(64, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       init_cfg={'type': 'Kaiming', 'layer': 'Conv2d'}
#     )
#   )
# )

# %%
## Export to ONNX
import torch

#torch.onnx.export(model.pts_voxel_layer, pc, 'centrpoint.onnx', verbose=True)
torch.onnx.export(sub_model, (voxels, num_points, coors), 'centrpoint.onnx', 
                  opset_version=11, verbose=True)
#torch.onnx.export(sub_model, (voxel_features, coors), 'centrpoint.onnx', 
#                  opset_version=10, verbose=True)

#data_in = torch.randn([1, 64, 128, 128]).cuda()

#torch.onnx.export(model, data_in, 'centrpoint.onnx', verbose=True)
# Out:
# graph(%0 : Float(241, 20, 4, strides=[80, 4, 1], requires_grad=0, device=cuda:0),
#       %num_points : Int(241, strides=[1], requires_grad=0, device=cuda:0),
#       %coors : Int(241, 4, strides=[4, 1], requires_grad=0, device=cuda:0),
#       %pts_voxel_encoder.pfn_layers.0.norm.weight : Float(64, strides=[1], requires_grad=1, device=cuda:0),
#       %pts_voxel_encoder.pfn_layers.0.norm.bias : Float(64, strides=[1], requires_grad=1, device=cuda:0),
#       %pts_voxel_encoder.pfn_layers.0.norm.running_mean : Float(64, strides=[1], requires_grad=0, device=cuda:0),
#       %pts_voxel_encoder.pfn_layers.0.norm.running_var : Float(64, strides=[1], requires_grad=0, device=cuda:0),
#       %pts_neck.deblocks.2.0.weight : Float(256, 128, 2, 2, strides=[512, 4, 2, 1], requires_grad=1, device=cuda:0),
#       %pts_neck.deblocks.2.1.weight : Float(128, strides=[1], requires_grad=1, device=cuda:0),
#       %pts_neck.deblocks.2.1.bias : Float(128, strides=[1], requires_grad=1, device=cuda:0),
#       %pts_neck.deblocks.2.1.running_mean : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %pts_neck.deblocks.2.1.running_var : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %pts_bbox_head.task_heads.0.reg.1.weight : Float(2, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %pts_bbox_head.task_heads.0.reg.1.bias : Float(2, strides=[1], requires_grad=1, device=cuda:0),
#       %pts_bbox_head.task_heads.0.height.1.weight : Float(1, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %pts_bbox_head.task_heads.0.height.1.bias : Float(1, strides=[1], requires_grad=1, device=cuda:0),
#       %pts_bbox_head.task_heads.0.dim.1.weight : Float(3, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %pts_bbox_head.task_heads.0.dim.1.bias : Float(3, strides=[1], requires_grad=1, device=cuda:0),
#       %pts_bbox_head.task_heads.0.rot.1.weight : Float(2, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %pts_bbox_head.task_heads.0.rot.1.bias : Float(2, strides=[1], requires_grad=1, device=cuda:0),
#       %pts_bbox_head.task_heads.0.heatmap.1.weight : Float(1, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %pts_bbox_head.task_heads.0.heatmap.1.bias : Float(1, strides=[1], requires_grad=1, device=cuda:0),
#       %pts_bbox_head.task_heads.1.reg.1.weight : Float(2, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %pts_bbox_head.task_heads.1.reg.1.bias : Float(2, strides=[1], requires_grad=1, device=cuda:0),
#       %pts_bbox_head.task_heads.1.height.1.weight : Float(1, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %pts_bbox_head.task_heads.1.height.1.bias : Float(1, strides=[1], requires_grad=1, device=cuda:0),
#       %pts_bbox_head.task_heads.1.dim.1.weight : Float(3, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %pts_bbox_head.task_heads.1.dim.1.bias : Float(3, strides=[1], requires_grad=1, device=cuda:0),
#       %pts_bbox_head.task_heads.1.rot.1.weight : Float(2, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %pts_bbox_head.task_heads.1.rot.1.bias : Float(2, strides=[1], requires_grad=1, device=cuda:0),
#       %pts_bbox_head.task_heads.1.heatmap.1.weight : Float(1, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %pts_bbox_head.task_heads.1.heatmap.1.bias : Float(1, strides=[1], requires_grad=1, device=cuda:0),
#       %pts_bbox_head.task_heads.2.reg.1.weight : Float(2, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %pts_bbox_head.task_heads.2.reg.1.bias : Float(2, strides=[1], requires_grad=1, device=cuda:0),
#       %pts_bbox_head.task_heads.2.height.1.weight : Float(1, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %pts_bbox_head.task_heads.2.height.1.bias : Float(1, strides=[1], requires_grad=1, device=cuda:0),
#       %pts_bbox_head.task_heads.2.dim.1.weight : Float(3, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %pts_bbox_head.task_heads.2.dim.1.bias : Float(3, strides=[1], requires_grad=1, device=cuda:0),
#       %pts_bbox_head.task_heads.2.rot.1.weight : Float(2, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %pts_bbox_head.task_heads.2.rot.1.bias : Float(2, strides=[1], requires_grad=1, device=cuda:0),
#       %pts_bbox_head.task_heads.2.heatmap.1.weight : Float(1, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %pts_bbox_head.task_heads.2.heatmap.1.bias : Float(1, strides=[1], requires_grad=1, device=cuda:0),
#       %pts_bbox_head.task_heads.3.reg.1.weight : Float(2, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %pts_bbox_head.task_heads.3.reg.1.bias : Float(2, strides=[1], requires_grad=1, device=cuda:0),
#       %pts_bbox_head.task_heads.3.height.1.weight : Float(1, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %pts_bbox_head.task_heads.3.height.1.bias : Float(1, strides=[1], requires_grad=1, device=cuda:0),
#       %pts_bbox_head.task_heads.3.dim.1.weight : Float(3, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %pts_bbox_head.task_heads.3.dim.1.bias : Float(3, strides=[1], requires_grad=1, device=cuda:0),
#       %pts_bbox_head.task_heads.3.rot.1.weight : Float(2, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %pts_bbox_head.task_heads.3.rot.1.bias : Float(2, strides=[1], requires_grad=1, device=cuda:0),
#       %pts_bbox_head.task_heads.3.heatmap.1.weight : Float(1, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %pts_bbox_head.task_heads.3.heatmap.1.bias : Float(1, strides=[1], requires_grad=1, device=cuda:0),
#       %746 : Float(64, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %747 : Float(64, strides=[1], requires_grad=0, device=cuda:0),
#       %749 : Float(64, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %750 : Float(64, strides=[1], requires_grad=0, device=cuda:0),
#       %752 : Float(64, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %753 : Float(64, strides=[1], requires_grad=0, device=cuda:0),
#       %755 : Float(64, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %756 : Float(64, strides=[1], requires_grad=0, device=cuda:0),
#       %758 : Float(128, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %759 : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %761 : Float(128, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %762 : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %764 : Float(128, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %765 : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %767 : Float(128, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %768 : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %770 : Float(128, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %771 : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %773 : Float(128, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %774 : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %776 : Float(256, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %777 : Float(256, strides=[1], requires_grad=0, device=cuda:0),
#       %779 : Float(256, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %780 : Float(256, strides=[1], requires_grad=0, device=cuda:0),
#       %782 : Float(256, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %783 : Float(256, strides=[1], requires_grad=0, device=cuda:0),
#       %785 : Float(256, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %786 : Float(256, strides=[1], requires_grad=0, device=cuda:0),
#       %788 : Float(256, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %789 : Float(256, strides=[1], requires_grad=0, device=cuda:0),
#       %791 : Float(256, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %792 : Float(256, strides=[1], requires_grad=0, device=cuda:0),
#       %794 : Float(128, 64, 2, 2, strides=[256, 4, 2, 1], requires_grad=0, device=cuda:0),
#       %795 : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %797 : Float(128, 128, 1, 1, strides=[128, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %798 : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %800 : Float(64, 384, 3, 3, strides=[3456, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %801 : Float(64, strides=[1], requires_grad=0, device=cuda:0),
#       %803 : Float(64, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %804 : Float(64, strides=[1], requires_grad=0, device=cuda:0),
#       %806 : Float(64, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %807 : Float(64, strides=[1], requires_grad=0, device=cuda:0),
#       %809 : Float(64, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %810 : Float(64, strides=[1], requires_grad=0, device=cuda:0),
#       %812 : Float(64, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %813 : Float(64, strides=[1], requires_grad=0, device=cuda:0),
#       %815 : Float(64, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %816 : Float(64, strides=[1], requires_grad=0, device=cuda:0),
#       %818 : Float(64, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %819 : Float(64, strides=[1], requires_grad=0, device=cuda:0),
#       %821 : Float(64, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %822 : Float(64, strides=[1], requires_grad=0, device=cuda:0),
#       %824 : Float(64, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %825 : Float(64, strides=[1], requires_grad=0, device=cuda:0),
#       %827 : Float(64, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %828 : Float(64, strides=[1], requires_grad=0, device=cuda:0),
#       %830 : Float(64, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %831 : Float(64, strides=[1], requires_grad=0, device=cuda:0),
#       %833 : Float(64, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %834 : Float(64, strides=[1], requires_grad=0, device=cuda:0),
#       %836 : Float(64, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %837 : Float(64, strides=[1], requires_grad=0, device=cuda:0),
#       %839 : Float(64, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %840 : Float(64, strides=[1], requires_grad=0, device=cuda:0),
#       %842 : Float(64, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %843 : Float(64, strides=[1], requires_grad=0, device=cuda:0),
#       %845 : Float(64, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %846 : Float(64, strides=[1], requires_grad=0, device=cuda:0),
#       %848 : Float(64, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %849 : Float(64, strides=[1], requires_grad=0, device=cuda:0),
#       %851 : Float(64, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %852 : Float(64, strides=[1], requires_grad=0, device=cuda:0),
#       %854 : Float(64, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %855 : Float(64, strides=[1], requires_grad=0, device=cuda:0),
#       %857 : Float(64, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %858 : Float(64, strides=[1], requires_grad=0, device=cuda:0),
#       %860 : Float(64, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %861 : Float(64, strides=[1], requires_grad=0, device=cuda:0),
#       %863 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %865 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %867 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %868 : Float(10, 64, strides=[1, 10], requires_grad=0, device=cuda:0)):
#   %289 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={2}]()
#   %290 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={0}]()
#   %291 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={3}]()
#   %292 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={1}]()
#   %293 : Float(241, 20, 3, strides=[80, 4, 1], requires_grad=0, device=cuda:0) = onnx::Slice(%0, %290, %291, %289, %292) # /home/mark/Code/mmdetection3d/mmdet3d/models/voxel_encoders/pillar_encoder.py:109:0
#   %294 : Float(241, 1, 3, strides=[3, 3, 1], requires_grad=0, device=cuda:0) = onnx::ReduceSum[axes=[1], keepdims=1](%293) # /home/mark/Code/mmdetection3d/mmdet3d/models/voxel_encoders/pillar_encoder.py:110:0
#   %295 : Float(241, strides=[1], requires_grad=0, device=cuda:0) = onnx::Cast[to=1](%num_points) # /home/mark/Code/mmdetection3d/mmdet3d/models/voxel_encoders/pillar_encoder.py:110:0
#   %296 : Long(3, strides=[1], device=cpu) = onnx::Constant[value=-1  1  1 [ CPULongType{3} ]]()
#   %297 : Float(241, 1, 1, strides=[1, 1, 1], requires_grad=0, device=cuda:0) = onnx::Reshape(%295, %296) # /home/mark/Code/mmdetection3d/mmdet3d/models/voxel_encoders/pillar_encoder.py:111:0
#   %298 : Float(241, 1, 3, strides=[3, 3, 1], requires_grad=0, device=cuda:0) = onnx::Div(%294, %297) # /home/mark/Code/mmdetection3d/mmdet3d/models/voxel_encoders/pillar_encoder.py:111:0
#   %299 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={2}]()
#   %300 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={0}]()
#   %301 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={3}]()
#   %302 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={1}]()
#   %303 : Float(241, 20, 3, strides=[80, 4, 1], requires_grad=0, device=cuda:0) = onnx::Slice(%0, %300, %301, %299, %302) # /home/mark/Code/mmdetection3d/mmdet3d/models/voxel_encoders/pillar_encoder.py:112:0
#   %304 : Float(241, 20, 3, strides=[60, 3, 1], requires_grad=0, device=cuda:0) = onnx::Sub(%303, %298) # /home/mark/Code/mmdetection3d/mmdet3d/models/voxel_encoders/pillar_encoder.py:112:0
#   %305 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={2}]()
#   %306 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={0}]()
#   %307 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={3}]()
#   %308 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={1}]()
#   %309 : Float(241, 20, 3, strides=[80, 4, 1], requires_grad=0, device=cuda:0) = onnx::Slice(%0, %306, %307, %305, %308) # /home/mark/Code/mmdetection3d/mmdet3d/models/voxel_encoders/pillar_encoder.py:119:0
#   %310 : Long(3, strides=[1], device=cpu) = onnx::Shape(%309)
#   %311 : Float(*, *, *, strides=[60, 3, 1], requires_grad=0, device=cuda:0) = onnx::ConstantOfShape[value={0}](%310) # /home/mark/Code/mmdetection3d/mmdet3d/models/voxel_encoders/pillar_encoder.py:122:0
#   %312 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={0}]()
#   %313 : Float(241, 20, strides=[80, 4], requires_grad=0, device=cuda:0) = onnx::Gather[axis=2](%0, %312) # /home/mark/Code/mmdetection3d/mmdet3d/models/voxel_encoders/pillar_encoder.py:120:0
#   %314 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={3}]()
#   %315 : Int(241, strides=[4], requires_grad=0, device=cuda:0) = onnx::Gather[axis=1](%coors, %314) # /home/mark/Code/mmdetection3d/mmdet3d/models/voxel_encoders/pillar_encoder.py:121:0
#   %316 : Float(241, strides=[1], requires_grad=0, device=cuda:0) = onnx::Cast[to=1](%315) # /home/mark/Code/mmdetection3d/mmdet3d/models/voxel_encoders/pillar_encoder.py:121:0
#   %317 : Float(241, 1, strides=[1, 1], requires_grad=0, device=cuda:0) = onnx::Unsqueeze[axes=[1]](%316) # /home/mark/Code/mmdetection3d/mmdet3d/models/voxel_encoders/pillar_encoder.py:121:0
#   %318 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={0.2}]()
#   %319 : Float(241, 1, strides=[1, 1], requires_grad=0, device=cuda:0) = onnx::Mul(%317, %318)
#   %320 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={0.1}]()
#   %321 : Float(241, 1, strides=[1, 1], requires_grad=0, device=cuda:0) = onnx::Add(%319, %320)
#   %322 : Float(241, 20, strides=[20, 1], requires_grad=0, device=cuda:0) = onnx::Sub(%313, %321) # /home/mark/Code/mmdetection3d/mmdet3d/models/voxel_encoders/pillar_encoder.py:122:0
#   %323 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={0}]()
#   %324 : Float(*, *, strides=[60, 3], requires_grad=0, device=cuda:0) = onnx::Gather[axis=2](%311, %323) # /home/mark/Code/mmdetection3d/mmdet3d/models/voxel_encoders/pillar_encoder.py:122:0
#   %325 : Long(2, strides=[1], device=cpu) = onnx::Shape(%324)
#   %326 : Float(241, 20, strides=[20, 1], requires_grad=0, device=cuda:0) = onnx::Expand(%322, %325) # /home/mark/Code/mmdetection3d/mmdet3d/models/voxel_encoders/pillar_encoder.py:122:0
#   %327 : Long(3, strides=[1], device=cpu) = onnx::Shape(%311)
#   %328 : Long(device=cpu) = onnx::Constant[value={0}]()
#   %329 : Long(device=cpu) = onnx::Gather[axis=0](%327, %328)
#   %330 : Long(device=cpu) = onnx::Cast[to=7](%329)
#   %331 : Long(device=cpu) = onnx::Constant[value={0}]()
#   %332 : Long(device=cpu) = onnx::Constant[value={1}]()
#   %333 : Long(*, device=cpu) = onnx::Range(%331, %330, %332)
#   %334 : Long(3, strides=[1], device=cpu) = onnx::Shape(%311)
#   %335 : Long(device=cpu) = onnx::Constant[value={1}]()
#   %336 : Long(device=cpu) = onnx::Gather[axis=0](%334, %335)
#   %337 : Long(device=cpu) = onnx::Cast[to=7](%336)
#   %338 : Long(device=cpu) = onnx::Constant[value={0}]()
#   %339 : Long(device=cpu) = onnx::Constant[value={1}]()
#   %340 : Long(*, device=cpu) = onnx::Range(%338, %337, %339)
#   %342 : Long(3, strides=[1], device=cpu) = onnx::Constant[value=-1  1  1 [ CPULongType{3} ]]()
#   %343 : Long(*, 1, 1, device=cpu) = onnx::Reshape(%333, %342)
#   %344 : Long(2, strides=[1], device=cpu) = onnx::Constant[value=-1  1 [ CPULongType{2} ]]()
#   %345 : Long(*, 1, device=cpu) = onnx::Reshape(%340, %344)
#   %348 : Long(*, *, 1, device=cpu) = onnx::Add(%343, %345)
#   %349 : Long(*, *, 1, device=cpu) = onnx::Add(%348, %863)
#   %350 : Long(3, strides=[1], device=cpu) = onnx::Shape(%349)
#   %351 : Long(1, strides=[1], device=cpu) = onnx::Shape(%350)
#   %352 : Long(*, device=cpu) = onnx::ConstantOfShape[value={1}](%351)
#   %353 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={-1}]()
#   %354 : Long(*, device=cpu) = onnx::Mul(%352, %353)
#   %355 : Bool(3, strides=[1], device=cpu) = onnx::Equal(%350, %354)
#   %356 : Long(3, strides=[1], device=cpu) = onnx::Where(%355, %352, %350)
#   %357 : LongTensor(device=cpu) = onnx::Expand(%343, %356)
#   %358 : LongTensor(device=cpu) = onnx::Unsqueeze[axes=[-1]](%357)
#   %359 : Long(1, strides=[1], device=cpu) = onnx::Shape(%350)
#   %360 : Long(*, device=cpu) = onnx::ConstantOfShape[value={1}](%359)
#   %361 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={-1}]()
#   %362 : Long(*, device=cpu) = onnx::Mul(%360, %361)
#   %363 : Bool(3, strides=[1], device=cpu) = onnx::Equal(%350, %362)
#   %364 : Long(3, strides=[1], device=cpu) = onnx::Where(%363, %360, %350)
#   %365 : LongTensor(device=cpu) = onnx::Expand(%345, %364)
#   %366 : LongTensor(device=cpu) = onnx::Unsqueeze[axes=[-1]](%365)
#   %367 : Long(1, strides=[1], device=cpu) = onnx::Shape(%350)
#   %368 : Long(*, device=cpu) = onnx::ConstantOfShape[value={1}](%367)
#   %369 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={-1}]()
#   %370 : Long(*, device=cpu) = onnx::Mul(%368, %369)
#   %371 : Bool(3, strides=[1], device=cpu) = onnx::Equal(%350, %370)
#   %372 : Long(3, strides=[1], device=cpu) = onnx::Where(%371, %368, %350)
#   %373 : LongTensor(device=cpu) = onnx::Expand(%863, %372)
#   %374 : LongTensor(device=cpu) = onnx::Unsqueeze[axes=[-1]](%373)
#   %375 : LongTensor(device=cpu) = onnx::Concat[axis=-1](%358, %366, %374)
#   %376 : Long(3, strides=[1], device=cpu) = onnx::Shape(%311)
#   %377 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={0}]()
#   %378 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={3}]()
#   %379 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={9223372036854775807}]()
#   %380 : Long(0, strides=[1], device=cpu) = onnx::Slice(%376, %378, %379, %377)
#   %381 : Long(3, strides=[1], device=cpu) = onnx::Concat[axis=0](%350, %380)
#   %382 : FloatTensor(device=cpu) = onnx::Reshape(%326, %381)
#   %383 : Float(*, *, *, strides=[60, 3, 1], requires_grad=0, device=cuda:0) = onnx::ScatterND(%311, %375, %382) # /home/mark/Code/mmdetection3d/mmdet3d/models/voxel_encoders/pillar_encoder.py:125:0
#   %384 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={1}]()
#   %385 : Float(241, 20, strides=[80, 4], requires_grad=0, device=cuda:0) = onnx::Gather[axis=2](%0, %384) # /home/mark/Code/mmdetection3d/mmdet3d/models/voxel_encoders/pillar_encoder.py:123:0
#   %386 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={2}]()
#   %387 : Int(241, strides=[4], requires_grad=0, device=cuda:0) = onnx::Gather[axis=1](%coors, %386) # /home/mark/Code/mmdetection3d/mmdet3d/models/voxel_encoders/pillar_encoder.py:124:0
#   %388 : Float(241, strides=[1], requires_grad=0, device=cuda:0) = onnx::Cast[to=1](%387) # /home/mark/Code/mmdetection3d/mmdet3d/models/voxel_encoders/pillar_encoder.py:124:0
#   %389 : Float(241, 1, strides=[1, 1], requires_grad=0, device=cuda:0) = onnx::Unsqueeze[axes=[1]](%388) # /home/mark/Code/mmdetection3d/mmdet3d/models/voxel_encoders/pillar_encoder.py:124:0
#   %390 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={0.2}]()
#   %391 : Float(241, 1, strides=[1, 1], requires_grad=0, device=cuda:0) = onnx::Mul(%389, %390)
#   %392 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={-55.1}]()
#   %393 : Float(241, 1, strides=[1, 1], requires_grad=0, device=cuda:0) = onnx::Add(%391, %392)
#   %394 : Float(241, 20, strides=[20, 1], requires_grad=0, device=cuda:0) = onnx::Sub(%385, %393) # /home/mark/Code/mmdetection3d/mmdet3d/models/voxel_encoders/pillar_encoder.py:125:0
#   %395 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={1}]()
#   %396 : Float(*, *, strides=[60, 3], requires_grad=0, device=cuda:0) = onnx::Gather[axis=2](%383, %395) # /home/mark/Code/mmdetection3d/mmdet3d/models/voxel_encoders/pillar_encoder.py:125:0
#   %397 : Long(2, strides=[1], device=cpu) = onnx::Shape(%396)
#   %398 : Float(241, 20, strides=[20, 1], requires_grad=0, device=cuda:0) = onnx::Expand(%394, %397) # /home/mark/Code/mmdetection3d/mmdet3d/models/voxel_encoders/pillar_encoder.py:125:0
#   %399 : Long(3, strides=[1], device=cpu) = onnx::Shape(%383)
#   %400 : Long(device=cpu) = onnx::Constant[value={0}]()
#   %401 : Long(device=cpu) = onnx::Gather[axis=0](%399, %400)
#   %402 : Long(device=cpu) = onnx::Cast[to=7](%401)
#   %403 : Long(device=cpu) = onnx::Constant[value={0}]()
#   %404 : Long(device=cpu) = onnx::Constant[value={1}]()
#   %405 : Long(*, device=cpu) = onnx::Range(%403, %402, %404)
#   %406 : Long(3, strides=[1], device=cpu) = onnx::Shape(%383)
#   %407 : Long(device=cpu) = onnx::Constant[value={1}]()
#   %408 : Long(device=cpu) = onnx::Gather[axis=0](%406, %407)
#   %409 : Long(device=cpu) = onnx::Cast[to=7](%408)
#   %410 : Long(device=cpu) = onnx::Constant[value={0}]()
#   %411 : Long(device=cpu) = onnx::Constant[value={1}]()
#   %412 : Long(*, device=cpu) = onnx::Range(%410, %409, %411)
#   %414 : Long(3, strides=[1], device=cpu) = onnx::Constant[value=-1  1  1 [ CPULongType{3} ]]()
#   %415 : Long(*, 1, 1, device=cpu) = onnx::Reshape(%405, %414)
#   %416 : Long(2, strides=[1], device=cpu) = onnx::Constant[value=-1  1 [ CPULongType{2} ]]()
#   %417 : Long(*, 1, device=cpu) = onnx::Reshape(%412, %416)
#   %420 : Long(*, *, 1, device=cpu) = onnx::Add(%415, %417)
#   %421 : Long(*, *, 1, device=cpu) = onnx::Add(%420, %865)
#   %422 : Long(3, strides=[1], device=cpu) = onnx::Shape(%421)
#   %423 : Long(1, strides=[1], device=cpu) = onnx::Shape(%422)
#   %424 : Long(*, device=cpu) = onnx::ConstantOfShape[value={1}](%423)
#   %425 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={-1}]()
#   %426 : Long(*, device=cpu) = onnx::Mul(%424, %425)
#   %427 : Bool(3, strides=[1], device=cpu) = onnx::Equal(%422, %426)
#   %428 : Long(3, strides=[1], device=cpu) = onnx::Where(%427, %424, %422)
#   %429 : LongTensor(device=cpu) = onnx::Expand(%415, %428)
#   %430 : LongTensor(device=cpu) = onnx::Unsqueeze[axes=[-1]](%429)
#   %431 : Long(1, strides=[1], device=cpu) = onnx::Shape(%422)
#   %432 : Long(*, device=cpu) = onnx::ConstantOfShape[value={1}](%431)
#   %433 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={-1}]()
#   %434 : Long(*, device=cpu) = onnx::Mul(%432, %433)
#   %435 : Bool(3, strides=[1], device=cpu) = onnx::Equal(%422, %434)
#   %436 : Long(3, strides=[1], device=cpu) = onnx::Where(%435, %432, %422)
#   %437 : LongTensor(device=cpu) = onnx::Expand(%417, %436)
#   %438 : LongTensor(device=cpu) = onnx::Unsqueeze[axes=[-1]](%437)
#   %439 : Long(1, strides=[1], device=cpu) = onnx::Shape(%422)
#   %440 : Long(*, device=cpu) = onnx::ConstantOfShape[value={1}](%439)
#   %441 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={-1}]()
#   %442 : Long(*, device=cpu) = onnx::Mul(%440, %441)
#   %443 : Bool(3, strides=[1], device=cpu) = onnx::Equal(%422, %442)
#   %444 : Long(3, strides=[1], device=cpu) = onnx::Where(%443, %440, %422)
#   %445 : LongTensor(device=cpu) = onnx::Expand(%865, %444)
#   %446 : LongTensor(device=cpu) = onnx::Unsqueeze[axes=[-1]](%445)
#   %447 : LongTensor(device=cpu) = onnx::Concat[axis=-1](%430, %438, %446)
#   %448 : Long(3, strides=[1], device=cpu) = onnx::Shape(%383)
#   %449 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={0}]()
#   %450 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={3}]()
#   %451 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={9223372036854775807}]()
#   %452 : Long(0, strides=[1], device=cpu) = onnx::Slice(%448, %450, %451, %449)
#   %453 : Long(3, strides=[1], device=cpu) = onnx::Concat[axis=0](%422, %452)
#   %454 : FloatTensor(device=cpu) = onnx::Reshape(%398, %453)
#   %455 : Float(*, *, *, strides=[60, 3, 1], requires_grad=0, device=cuda:0) = onnx::ScatterND(%383, %447, %454) # /home/mark/Code/mmdetection3d/mmdet3d/models/voxel_encoders/pillar_encoder.py:128:0
#   %456 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={2}]()
#   %457 : Float(241, 20, strides=[80, 4], requires_grad=0, device=cuda:0) = onnx::Gather[axis=2](%0, %456) # /home/mark/Code/mmdetection3d/mmdet3d/models/voxel_encoders/pillar_encoder.py:126:0
#   %458 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={1}]()
#   %459 : Int(241, strides=[4], requires_grad=0, device=cuda:0) = onnx::Gather[axis=1](%coors, %458) # /home/mark/Code/mmdetection3d/mmdet3d/models/voxel_encoders/pillar_encoder.py:127:0
#   %460 : Float(241, strides=[1], requires_grad=0, device=cuda:0) = onnx::Cast[to=1](%459) # /home/mark/Code/mmdetection3d/mmdet3d/models/voxel_encoders/pillar_encoder.py:127:0
#   %461 : Float(241, 1, strides=[1, 1], requires_grad=0, device=cuda:0) = onnx::Unsqueeze[axes=[1]](%460) # /home/mark/Code/mmdetection3d/mmdet3d/models/voxel_encoders/pillar_encoder.py:127:0
#   %462 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={16}]()
#   %463 : Float(241, 1, strides=[1, 1], requires_grad=0, device=cuda:0) = onnx::Mul(%461, %462)
#   %464 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={-7}]()
#   %465 : Float(241, 1, strides=[1, 1], requires_grad=0, device=cuda:0) = onnx::Add(%463, %464)
#   %466 : Float(241, 20, strides=[20, 1], requires_grad=0, device=cuda:0) = onnx::Sub(%457, %465) # /home/mark/Code/mmdetection3d/mmdet3d/models/voxel_encoders/pillar_encoder.py:128:0
#   %467 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={2}]()
#   %468 : Float(*, *, strides=[60, 3], requires_grad=0, device=cuda:0) = onnx::Gather[axis=2](%455, %467) # /home/mark/Code/mmdetection3d/mmdet3d/models/voxel_encoders/pillar_encoder.py:128:0
#   %469 : Long(2, strides=[1], device=cpu) = onnx::Shape(%468)
#   %470 : Float(241, 20, strides=[20, 1], requires_grad=0, device=cuda:0) = onnx::Expand(%466, %469) # /home/mark/Code/mmdetection3d/mmdet3d/models/voxel_encoders/pillar_encoder.py:128:0
#   %471 : Long(3, strides=[1], device=cpu) = onnx::Shape(%455)
#   %472 : Long(device=cpu) = onnx::Constant[value={0}]()
#   %473 : Long(device=cpu) = onnx::Gather[axis=0](%471, %472)
#   %474 : Long(device=cpu) = onnx::Cast[to=7](%473)
#   %475 : Long(device=cpu) = onnx::Constant[value={0}]()
#   %476 : Long(device=cpu) = onnx::Constant[value={1}]()
#   %477 : Long(*, device=cpu) = onnx::Range(%475, %474, %476)
#   %478 : Long(3, strides=[1], device=cpu) = onnx::Shape(%455)
#   %479 : Long(device=cpu) = onnx::Constant[value={1}]()
#   %480 : Long(device=cpu) = onnx::Gather[axis=0](%478, %479)
#   %481 : Long(device=cpu) = onnx::Cast[to=7](%480)
#   %482 : Long(device=cpu) = onnx::Constant[value={0}]()
#   %483 : Long(device=cpu) = onnx::Constant[value={1}]()
#   %484 : Long(*, device=cpu) = onnx::Range(%482, %481, %483)
#   %486 : Long(3, strides=[1], device=cpu) = onnx::Constant[value=-1  1  1 [ CPULongType{3} ]]()
#   %487 : Long(*, 1, 1, device=cpu) = onnx::Reshape(%477, %486)
#   %488 : Long(2, strides=[1], device=cpu) = onnx::Constant[value=-1  1 [ CPULongType{2} ]]()
#   %489 : Long(*, 1, device=cpu) = onnx::Reshape(%484, %488)
#   %492 : Long(*, *, 1, device=cpu) = onnx::Add(%487, %489)
#   %493 : Long(*, *, 1, device=cpu) = onnx::Add(%492, %867)
#   %494 : Long(3, strides=[1], device=cpu) = onnx::Shape(%493)
#   %495 : Long(1, strides=[1], device=cpu) = onnx::Shape(%494)
#   %496 : Long(*, device=cpu) = onnx::ConstantOfShape[value={1}](%495)
#   %497 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={-1}]()
#   %498 : Long(*, device=cpu) = onnx::Mul(%496, %497)
#   %499 : Bool(3, strides=[1], device=cpu) = onnx::Equal(%494, %498)
#   %500 : Long(3, strides=[1], device=cpu) = onnx::Where(%499, %496, %494)
#   %501 : LongTensor(device=cpu) = onnx::Expand(%487, %500)
#   %502 : LongTensor(device=cpu) = onnx::Unsqueeze[axes=[-1]](%501)
#   %503 : Long(1, strides=[1], device=cpu) = onnx::Shape(%494)
#   %504 : Long(*, device=cpu) = onnx::ConstantOfShape[value={1}](%503)
#   %505 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={-1}]()
#   %506 : Long(*, device=cpu) = onnx::Mul(%504, %505)
#   %507 : Bool(3, strides=[1], device=cpu) = onnx::Equal(%494, %506)
#   %508 : Long(3, strides=[1], device=cpu) = onnx::Where(%507, %504, %494)
#   %509 : LongTensor(device=cpu) = onnx::Expand(%489, %508)
#   %510 : LongTensor(device=cpu) = onnx::Unsqueeze[axes=[-1]](%509)
#   %511 : Long(1, strides=[1], device=cpu) = onnx::Shape(%494)
#   %512 : Long(*, device=cpu) = onnx::ConstantOfShape[value={1}](%511)
#   %513 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={-1}]()
#   %514 : Long(*, device=cpu) = onnx::Mul(%512, %513)
#   %515 : Bool(3, strides=[1], device=cpu) = onnx::Equal(%494, %514)
#   %516 : Long(3, strides=[1], device=cpu) = onnx::Where(%515, %512, %494)
#   %517 : LongTensor(device=cpu) = onnx::Expand(%867, %516)
#   %518 : LongTensor(device=cpu) = onnx::Unsqueeze[axes=[-1]](%517)
#   %519 : LongTensor(device=cpu) = onnx::Concat[axis=-1](%502, %510, %518)
#   %520 : Long(3, strides=[1], device=cpu) = onnx::Shape(%455)
#   %521 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={0}]()
#   %522 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={3}]()
#   %523 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={9223372036854775807}]()
#   %524 : Long(0, strides=[1], device=cpu) = onnx::Slice(%520, %522, %523, %521)
#   %525 : Long(3, strides=[1], device=cpu) = onnx::Concat[axis=0](%494, %524)
#   %526 : FloatTensor(device=cpu) = onnx::Reshape(%470, %525)
#   %527 : Float(*, *, *, requires_grad=0, device=cuda:0) = onnx::ScatterND(%455, %519, %526)
#   %528 : Float(241, 20, *, strides=[200, 10, 1], requires_grad=0, device=cuda:0) = onnx::Concat[axis=-1](%0, %304, %527) # /home/mark/Code/mmdetection3d/mmdet3d/models/voxel_encoders/pillar_encoder.py:147:0
#   %529 : Long(3, strides=[1], device=cpu) = onnx::Shape(%528)
#   %530 : Long(device=cpu) = onnx::Constant[value={1}]()
#   %531 : Long(device=cpu) = onnx::Gather[axis=0](%529, %530) # /home/mark/Code/mmdetection3d/mmdet3d/models/voxel_encoders/pillar_encoder.py:151:0
#   %532 : Int(241, 1, strides=[1, 1], requires_grad=0, device=cuda:0) = onnx::Unsqueeze[axes=[1]](%num_points) # /home/mark/Code/mmdetection3d/mmdet3d/models/voxel_encoders/utils.py:19:0
#   %533 : Int(device=cpu) = onnx::Cast[to=6](%531)
#   %534 : Int(device=cpu) = onnx::Constant[value={0}]()
#   %535 : Int(device=cpu) = onnx::Constant[value={1}]()
#   %536 : Int(*, strides=[1], requires_grad=0, device=cuda:0) = onnx::Range(%534, %533, %535) # /home/mark/Code/mmdetection3d/mmdet3d/models/voxel_encoders/utils.py:24:0
#   %537 : Long(2, strides=[1], device=cpu) = onnx::Constant[value= 1 -1 [ CPULongType{2} ]]()
#   %538 : Int(1, *, strides=[20, 1], requires_grad=0, device=cuda:0) = onnx::Reshape(%536, %537) # /home/mark/Code/mmdetection3d/mmdet3d/models/voxel_encoders/utils.py:24:0
#   %539 : Int(241, 1, strides=[1, 1], requires_grad=0, device=cuda:0) = onnx::Cast[to=6](%532) # /home/mark/Code/mmdetection3d/mmdet3d/models/voxel_encoders/utils.py:27:0
#   %540 : Bool(241, *, strides=[20, 1], requires_grad=0, device=cuda:0) = onnx::Greater(%539, %538) # /home/mark/Code/mmdetection3d/mmdet3d/models/voxel_encoders/utils.py:27:0
#   %541 : Bool(241, *, 1, strides=[20, 1, 1], requires_grad=0, device=cuda:0) = onnx::Unsqueeze[axes=[-1]](%540) # /home/mark/Code/mmdetection3d/mmdet3d/models/voxel_encoders/pillar_encoder.py:153:0
#   %542 : Float(241, *, 1, strides=[20, 1, 1], requires_grad=0, device=cuda:0) = onnx::Cast[to=1](%541)
#   %543 : Float(241, 20, *, strides=[200, 10, 1], requires_grad=0, device=cuda:0) = onnx::Mul(%528, %542) # /home/mark/Code/mmdetection3d/mmdet3d/models/voxel_encoders/pillar_encoder.py:154:0
#   %545 : Float(241, 20, 64, strides=[1280, 64, 1], requires_grad=1, device=cuda:0) = onnx::MatMul(%543, %868) # /home/mark/.local/lib/python3.6/site-packages/torch/nn/functional.py:1753:0
#   %546 : Float(241, 64, 20, strides=[1280, 20, 1], requires_grad=1, device=cuda:0) = onnx::Transpose[perm=[0, 2, 1]](%545) # /home/mark/Code/mmdetection3d/mmdet3d/models/voxel_encoders/utils.py:162:0
#   %547 : Float(241, 64, 20, strides=[1280, 20, 1], requires_grad=1, device=cuda:0) = onnx::BatchNormalization[epsilon=0.001, momentum=0.98999999999999999](%546, %pts_voxel_encoder.pfn_layers.0.norm.weight, %pts_voxel_encoder.pfn_layers.0.norm.bias, %pts_voxel_encoder.pfn_layers.0.norm.running_mean, %pts_voxel_encoder.pfn_layers.0.norm.running_var) # /home/mark/.local/lib/python3.6/site-packages/torch/nn/functional.py:2150:0
#   %548 : Float(241, 20, 64, strides=[1280, 64, 1], requires_grad=1, device=cuda:0) = onnx::Transpose[perm=[0, 2, 1]](%547) # /home/mark/Code/mmdetection3d/mmdet3d/models/voxel_encoders/utils.py:163:0
#   %549 : Float(241, 20, 64, strides=[1280, 64, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%548) # /home/mark/.local/lib/python3.6/site-packages/torch/nn/functional.py:1206:0
#   %550 : Float(241, 1, 64, strides=[64, 64, 1], requires_grad=1, device=cuda:0) = onnx::ReduceMax[axes=[1], keepdims=1](%549) # /home/mark/Code/mmdetection3d/mmdet3d/models/voxel_encoders/utils.py:169:0
#   %551 : Float(241, 64, strides=[64, 1], requires_grad=1, device=cuda:0) = onnx::Squeeze[axes=[1]](%550) # /home/mark/Code/mmdetection3d/mmdet3d/models/voxel_encoders/pillar_encoder.py:159:0
#   %552 : Long(2, strides=[1], device=cpu) = onnx::Constant[value=     64  353280 [ CPULongType{2} ]]()
#   %553 : Float(64, 353280, strides=[353280, 1], requires_grad=0, device=cuda:0) = onnx::ConstantOfShape[value={0}](%552) # /home/mark/Code/mmdetection3d/mmdet3d/models/middle_encoders/pillar_scatter.py:51:0
#   %554 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={2}]()
#   %555 : Int(241, strides=[4], requires_grad=0, device=cuda:0) = onnx::Gather[axis=1](%coors, %554) # /home/mark/Code/mmdetection3d/mmdet3d/models/middle_encoders/pillar_scatter.py:53:0
#   %556 : Int(requires_grad=0, device=cpu) = onnx::Constant[value={640}]()
#   %557 : Int(241, strides=[1], requires_grad=0, device=cuda:0) = onnx::Mul(%555, %556)
#   %558 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={3}]()
#   %559 : Int(241, strides=[4], requires_grad=0, device=cuda:0) = onnx::Gather[axis=1](%coors, %558) # /home/mark/Code/mmdetection3d/mmdet3d/models/middle_encoders/pillar_scatter.py:53:0
#   %560 : Int(241, strides=[1], requires_grad=0, device=cuda:0) = onnx::Add(%557, %559) # /home/mark/Code/mmdetection3d/mmdet3d/models/middle_encoders/pillar_scatter.py:53:0
#   %561 : Long(241, strides=[1], requires_grad=0, device=cuda:0) = onnx::Cast[to=7](%560) # /home/mark/Code/mmdetection3d/mmdet3d/models/middle_encoders/pillar_scatter.py:54:0
#   %562 : Float(64, 241, strides=[1, 64], requires_grad=1, device=cuda:0) = onnx::Transpose[perm=[1, 0]](%551) # /home/mark/Code/mmdetection3d/mmdet3d/models/middle_encoders/pillar_scatter.py:55:0
#   %563 : Long(241, strides=[1], requires_grad=0, device=cuda:0) = onnx::Cast[to=7](%561) # /home/mark/Code/mmdetection3d/mmdet3d/models/middle_encoders/pillar_scatter.py:57:0
#   %564 : Long(2, strides=[1], device=cpu) = onnx::Shape(%553)
#   %565 : Long(device=cpu) = onnx::Constant[value={0}]()
#   %566 : Long(device=cpu) = onnx::Gather[axis=0](%564, %565)
#   %567 : Long(device=cpu) = onnx::Cast[to=7](%566)
#   %568 : Long(device=cpu) = onnx::Constant[value={0}]()
#   %569 : Long(device=cpu) = onnx::Constant[value={1}]()
#   %570 : Long(*, device=cpu) = onnx::Range(%568, %567, %569)
#   %571 : Long(2, strides=[1], device=cpu) = onnx::Constant[value=-1  1 [ CPULongType{2} ]]()
#   %572 : Long(*, 1, device=cpu) = onnx::Reshape(%570, %571)
#   %573 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={-1}]()
#   %574 : Long(241, strides=[1], device=cpu) = onnx::Reshape(%563, %573)
#   %575 : Long(*, 241, device=cpu) = onnx::Add(%572, %574)
#   %576 : Long(2, strides=[1], device=cpu) = onnx::Shape(%575)
#   %577 : Long(1, strides=[1], device=cpu) = onnx::Shape(%576)
#   %578 : Long(*, device=cpu) = onnx::ConstantOfShape[value={1}](%577)
#   %579 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={-1}]()
#   %580 : Long(*, device=cpu) = onnx::Mul(%578, %579)
#   %581 : Bool(2, strides=[1], device=cpu) = onnx::Equal(%576, %580)
#   %582 : Long(2, strides=[1], device=cpu) = onnx::Where(%581, %578, %576)
#   %583 : LongTensor(device=cpu) = onnx::Expand(%572, %582)
#   %584 : LongTensor(device=cpu) = onnx::Unsqueeze[axes=[-1]](%583)
#   %585 : Long(1, strides=[1], device=cpu) = onnx::Shape(%576)
#   %586 : Long(*, device=cpu) = onnx::ConstantOfShape[value={1}](%585)
#   %587 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={-1}]()
#   %588 : Long(*, device=cpu) = onnx::Mul(%586, %587)
#   %589 : Bool(2, strides=[1], device=cpu) = onnx::Equal(%576, %588)
#   %590 : Long(2, strides=[1], device=cpu) = onnx::Where(%589, %586, %576)
#   %591 : LongTensor(device=cpu) = onnx::Expand(%574, %590)
#   %592 : LongTensor(device=cpu) = onnx::Unsqueeze[axes=[-1]](%591)
#   %593 : LongTensor(device=cpu) = onnx::Concat[axis=-1](%584, %592)
#   %594 : Long(2, strides=[1], device=cpu) = onnx::Shape(%553)
#   %595 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={0}]()
#   %596 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={2}]()
#   %597 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={9223372036854775807}]()
#   %598 : Long(0, strides=[1], device=cpu) = onnx::Slice(%594, %596, %597, %595)
#   %599 : Long(2, strides=[1], device=cpu) = onnx::Concat[axis=0](%576, %598)
#   %600 : FloatTensor(device=cpu) = onnx::Reshape(%562, %599)
#   %601 : Float(64, 353280, strides=[353280, 1], requires_grad=1, device=cuda:0) = onnx::ScatterND(%553, %593, %600)
#   %602 : Long(4, strides=[1], device=cpu) = onnx::Constant[value=   1   64  552  640 [ CPULongType{4} ]]()
#   %603 : Float(1, 64, 552, 640, strides=[22609920, 353280, 640, 1], requires_grad=1, device=cuda:0) = onnx::Reshape(%601, %602) # /home/mark/Code/mmdetection3d/mmdet3d/models/middle_encoders/pillar_scatter.py:59:0
#   %745 : Float(1, 64, 276, 320, strides=[5652480, 88320, 320, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2]](%603, %746, %747)
#   %606 : Float(1, 64, 276, 320, strides=[5652480, 88320, 320, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%745) # /home/mark/.local/lib/python3.6/site-packages/torch/nn/functional.py:1204:0
#   %748 : Float(1, 64, 276, 320, strides=[5652480, 88320, 320, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%606, %749, %750)
#   %609 : Float(1, 64, 276, 320, strides=[5652480, 88320, 320, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%748) # /home/mark/.local/lib/python3.6/site-packages/torch/nn/functional.py:1204:0
#   %751 : Float(1, 64, 276, 320, strides=[5652480, 88320, 320, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%609, %752, %753)
#   %612 : Float(1, 64, 276, 320, strides=[5652480, 88320, 320, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%751) # /home/mark/.local/lib/python3.6/site-packages/torch/nn/functional.py:1204:0
#   %754 : Float(1, 64, 276, 320, strides=[5652480, 88320, 320, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%612, %755, %756)
#   %615 : Float(1, 64, 276, 320, strides=[5652480, 88320, 320, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%754) # /home/mark/.local/lib/python3.6/site-packages/torch/nn/functional.py:1204:0
#   %757 : Float(1, 128, 138, 160, strides=[2826240, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2]](%615, %758, %759)
#   %618 : Float(1, 128, 138, 160, strides=[2826240, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%757) # /home/mark/.local/lib/python3.6/site-packages/torch/nn/functional.py:1204:0
#   %760 : Float(1, 128, 138, 160, strides=[2826240, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%618, %761, %762)
#   %621 : Float(1, 128, 138, 160, strides=[2826240, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%760) # /home/mark/.local/lib/python3.6/site-packages/torch/nn/functional.py:1204:0
#   %763 : Float(1, 128, 138, 160, strides=[2826240, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%621, %764, %765)
#   %624 : Float(1, 128, 138, 160, strides=[2826240, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%763) # /home/mark/.local/lib/python3.6/site-packages/torch/nn/functional.py:1204:0
#   %766 : Float(1, 128, 138, 160, strides=[2826240, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%624, %767, %768)
#   %627 : Float(1, 128, 138, 160, strides=[2826240, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%766) # /home/mark/.local/lib/python3.6/site-packages/torch/nn/functional.py:1204:0
#   %769 : Float(1, 128, 138, 160, strides=[2826240, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%627, %770, %771)
#   %630 : Float(1, 128, 138, 160, strides=[2826240, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%769) # /home/mark/.local/lib/python3.6/site-packages/torch/nn/functional.py:1204:0
#   %772 : Float(1, 128, 138, 160, strides=[2826240, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%630, %773, %774)
#   %633 : Float(1, 128, 138, 160, strides=[2826240, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%772) # /home/mark/.local/lib/python3.6/site-packages/torch/nn/functional.py:1204:0
#   %775 : Float(1, 256, 69, 80, strides=[1413120, 5520, 80, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2]](%633, %776, %777)
#   %636 : Float(1, 256, 69, 80, strides=[1413120, 5520, 80, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%775) # /home/mark/.local/lib/python3.6/site-packages/torch/nn/functional.py:1204:0
#   %778 : Float(1, 256, 69, 80, strides=[1413120, 5520, 80, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%636, %779, %780)
#   %639 : Float(1, 256, 69, 80, strides=[1413120, 5520, 80, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%778) # /home/mark/.local/lib/python3.6/site-packages/torch/nn/functional.py:1204:0
#   %781 : Float(1, 256, 69, 80, strides=[1413120, 5520, 80, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%639, %782, %783)
#   %642 : Float(1, 256, 69, 80, strides=[1413120, 5520, 80, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%781) # /home/mark/.local/lib/python3.6/site-packages/torch/nn/functional.py:1204:0
#   %784 : Float(1, 256, 69, 80, strides=[1413120, 5520, 80, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%642, %785, %786)
#   %645 : Float(1, 256, 69, 80, strides=[1413120, 5520, 80, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%784) # /home/mark/.local/lib/python3.6/site-packages/torch/nn/functional.py:1204:0
#   %787 : Float(1, 256, 69, 80, strides=[1413120, 5520, 80, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%645, %788, %789)
#   %648 : Float(1, 256, 69, 80, strides=[1413120, 5520, 80, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%787) # /home/mark/.local/lib/python3.6/site-packages/torch/nn/functional.py:1204:0
#   %790 : Float(1, 256, 69, 80, strides=[1413120, 5520, 80, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%648, %791, %792)
#   %651 : Float(1, 256, 69, 80, strides=[1413120, 5520, 80, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%790) # /home/mark/.local/lib/python3.6/site-packages/torch/nn/functional.py:1204:0
#   %793 : Float(1, 128, 138, 160, strides=[2826240, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[2, 2], pads=[0, 0, 0, 0], strides=[2, 2]](%615, %794, %795)
#   %654 : Float(1, 128, 138, 160, strides=[2826240, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%793) # /home/mark/.local/lib/python3.6/site-packages/torch/nn/functional.py:1204:0
#   %796 : Float(1, 128, 138, 160, strides=[2826240, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%633, %797, %798)
#   %657 : Float(1, 128, 138, 160, strides=[2826240, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%796) # /home/mark/.local/lib/python3.6/site-packages/torch/nn/functional.py:1204:0
#   %658 : Float(1, 128, 138, 160, strides=[2826240, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::ConvTranspose[dilations=[1, 1], group=1, kernel_shape=[2, 2], pads=[0, 0, 0, 0], strides=[2, 2]](%651, %pts_neck.deblocks.2.0.weight) # /home/mark/.local/lib/python3.6/site-packages/torch/nn/modules/conv.py:842:0
# ...
#   %799 : Float(1, 64, 138, 160, strides=[1413120, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%661, %800, %801)
#   %664 : Float(1, 64, 138, 160, strides=[1413120, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%799) # /home/mark/.local/lib/python3.6/site-packages/torch/nn/functional.py:1204:0
#   %802 : Float(1, 64, 138, 160, strides=[1413120, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%664, %803, %804)
#   %667 : Float(1, 64, 138, 160, strides=[1413120, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%802) # /home/mark/.local/lib/python3.6/site-packages/torch/nn/functional.py:1204:0
#   %668 : Float(1, 2, 138, 160, strides=[44160, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%667, %pts_bbox_head.task_heads.0.reg.1.weight, %pts_bbox_head.task_heads.0.reg.1.bias) # /home/mark/.local/lib/python3.6/site-packages/torch/nn/modules/conv.py:396:0
#   %805 : Float(1, 64, 138, 160, strides=[1413120, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%664, %806, %807)
#   %671 : Float(1, 64, 138, 160, strides=[1413120, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%805) # /home/mark/.local/lib/python3.6/site-packages/torch/nn/functional.py:1204:0
#   %672 : Float(1, 1, 138, 160, strides=[22080, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%671, %pts_bbox_head.task_heads.0.height.1.weight, %pts_bbox_head.task_heads.0.height.1.bias) # /home/mark/.local/lib/python3.6/site-packages/torch/nn/modules/conv.py:396:0
#   %808 : Float(1, 64, 138, 160, strides=[1413120, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%664, %809, %810)
#   %675 : Float(1, 64, 138, 160, strides=[1413120, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%808) # /home/mark/.local/lib/python3.6/site-packages/torch/nn/functional.py:1204:0
#   %676 : Float(1, 3, 138, 160, strides=[66240, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%675, %pts_bbox_head.task_heads.0.dim.1.weight, %pts_bbox_head.task_heads.0.dim.1.bias) # /home/mark/.local/lib/python3.6/site-packages/torch/nn/modules/conv.py:396:0
#   %811 : Float(1, 64, 138, 160, strides=[1413120, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%664, %812, %813)
#   %679 : Float(1, 64, 138, 160, strides=[1413120, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%811) # /home/mark/.local/lib/python3.6/site-packages/torch/nn/functional.py:1204:0
#   %680 : Float(1, 2, 138, 160, strides=[44160, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%679, %pts_bbox_head.task_heads.0.rot.1.weight, %pts_bbox_head.task_heads.0.rot.1.bias) # /home/mark/.local/lib/python3.6/site-packages/torch/nn/modules/conv.py:396:0
#   %814 : Float(1, 64, 138, 160, strides=[1413120, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%664, %815, %816)
#   %683 : Float(1, 64, 138, 160, strides=[1413120, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%814) # /home/mark/.local/lib/python3.6/site-packages/torch/nn/functional.py:1204:0
#   %684 : Float(1, 1, 138, 160, strides=[22080, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%683, %pts_bbox_head.task_heads.0.heatmap.1.weight, %pts_bbox_head.task_heads.0.heatmap.1.bias) # /home/mark/.local/lib/python3.6/site-packages/torch/nn/modules/conv.py:396:0
#   %817 : Float(1, 64, 138, 160, strides=[1413120, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%664, %818, %819)
#   %687 : Float(1, 64, 138, 160, strides=[1413120, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%817) # /home/mark/.local/lib/python3.6/site-packages/torch/nn/functional.py:1204:0
#   %688 : Float(1, 2, 138, 160, strides=[44160, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%687, %pts_bbox_head.task_heads.1.reg.1.weight, %pts_bbox_head.task_heads.1.reg.1.bias) # /home/mark/.local/lib/python3.6/site-packages/torch/nn/modules/conv.py:396:0
#   %820 : Float(1, 64, 138, 160, strides=[1413120, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%664, %821, %822)
#   %691 : Float(1, 64, 138, 160, strides=[1413120, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%820) # /home/mark/.local/lib/python3.6/site-packages/torch/nn/functional.py:1204:0
#   %692 : Float(1, 1, 138, 160, strides=[22080, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%691, %pts_bbox_head.task_heads.1.height.1.weight, %pts_bbox_head.task_heads.1.height.1.bias) # /home/mark/.local/lib/python3.6/site-packages/torch/nn/modules/conv.py:396:0
#   %823 : Float(1, 64, 138, 160, strides=[1413120, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%664, %824, %825)
#   %695 : Float(1, 64, 138, 160, strides=[1413120, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%823) # /home/mark/.local/lib/python3.6/site-packages/torch/nn/functional.py:1204:0
#   %696 : Float(1, 3, 138, 160, strides=[66240, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%695, %pts_bbox_head.task_heads.1.dim.1.weight, %pts_bbox_head.task_heads.1.dim.1.bias) # /home/mark/.local/lib/python3.6/site-packages/torch/nn/modules/conv.py:396:0
#   %826 : Float(1, 64, 138, 160, strides=[1413120, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%664, %827, %828)
#   %699 : Float(1, 64, 138, 160, strides=[1413120, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%826) # /home/mark/.local/lib/python3.6/site-packages/torch/nn/functional.py:1204:0
#   %700 : Float(1, 2, 138, 160, strides=[44160, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%699, %pts_bbox_head.task_heads.1.rot.1.weight, %pts_bbox_head.task_heads.1.rot.1.bias) # /home/mark/.local/lib/python3.6/site-packages/torch/nn/modules/conv.py:396:0
#   %829 : Float(1, 64, 138, 160, strides=[1413120, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%664, %830, %831)
#   %703 : Float(1, 64, 138, 160, strides=[1413120, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%829) # /home/mark/.local/lib/python3.6/site-packages/torch/nn/functional.py:1204:0
#   %704 : Float(1, 1, 138, 160, strides=[22080, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%703, %pts_bbox_head.task_heads.1.heatmap.1.weight, %pts_bbox_head.task_heads.1.heatmap.1.bias) # /home/mark/.local/lib/python3.6/site-packages/torch/nn/modules/conv.py:396:0
#   %832 : Float(1, 64, 138, 160, strides=[1413120, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%664, %833, %834)
#   %707 : Float(1, 64, 138, 160, strides=[1413120, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%832) # /home/mark/.local/lib/python3.6/site-packages/torch/nn/functional.py:1204:0
#   %708 : Float(1, 2, 138, 160, strides=[44160, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%707, %pts_bbox_head.task_heads.2.reg.1.weight, %pts_bbox_head.task_heads.2.reg.1.bias) # /home/mark/.local/lib/python3.6/site-packages/torch/nn/modules/conv.py:396:0
#   %835 : Float(1, 64, 138, 160, strides=[1413120, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%664, %836, %837)
#   %711 : Float(1, 64, 138, 160, strides=[1413120, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%835) # /home/mark/.local/lib/python3.6/site-packages/torch/nn/functional.py:1204:0
#   %712 : Float(1, 1, 138, 160, strides=[22080, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%711, %pts_bbox_head.task_heads.2.height.1.weight, %pts_bbox_head.task_heads.2.height.1.bias) # /home/mark/.local/lib/python3.6/site-packages/torch/nn/modules/conv.py:396:0
#   %838 : Float(1, 64, 138, 160, strides=[1413120, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%664, %839, %840)
#   %715 : Float(1, 64, 138, 160, strides=[1413120, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%838) # /home/mark/.local/lib/python3.6/site-packages/torch/nn/functional.py:1204:0
#   %716 : Float(1, 3, 138, 160, strides=[66240, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%715, %pts_bbox_head.task_heads.2.dim.1.weight, %pts_bbox_head.task_heads.2.dim.1.bias) # /home/mark/.local/lib/python3.6/site-packages/torch/nn/modules/conv.py:396:0
#   %841 : Float(1, 64, 138, 160, strides=[1413120, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%664, %842, %843)
#   %719 : Float(1, 64, 138, 160, strides=[1413120, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%841) # /home/mark/.local/lib/python3.6/site-packages/torch/nn/functional.py:1204:0
#   %720 : Float(1, 2, 138, 160, strides=[44160, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%719, %pts_bbox_head.task_heads.2.rot.1.weight, %pts_bbox_head.task_heads.2.rot.1.bias) # /home/mark/.local/lib/python3.6/site-packages/torch/nn/modules/conv.py:396:0
#   %844 : Float(1, 64, 138, 160, strides=[1413120, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%664, %845, %846)
#   %723 : Float(1, 64, 138, 160, strides=[1413120, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%844) # /home/mark/.local/lib/python3.6/site-packages/torch/nn/functional.py:1204:0
#   %724 : Float(1, 1, 138, 160, strides=[22080, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%723, %pts_bbox_head.task_heads.2.heatmap.1.weight, %pts_bbox_head.task_heads.2.heatmap.1.bias) # /home/mark/.local/lib/python3.6/site-packages/torch/nn/modules/conv.py:396:0
#   %847 : Float(1, 64, 138, 160, strides=[1413120, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%664, %848, %849)
#   %727 : Float(1, 64, 138, 160, strides=[1413120, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%847) # /home/mark/.local/lib/python3.6/site-packages/torch/nn/functional.py:1204:0
#   %728 : Float(1, 2, 138, 160, strides=[44160, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%727, %pts_bbox_head.task_heads.3.reg.1.weight, %pts_bbox_head.task_heads.3.reg.1.bias) # /home/mark/.local/lib/python3.6/site-packages/torch/nn/modules/conv.py:396:0
#   %850 : Float(1, 64, 138, 160, strides=[1413120, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%664, %851, %852)
#   %731 : Float(1, 64, 138, 160, strides=[1413120, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%850) # /home/mark/.local/lib/python3.6/site-packages/torch/nn/functional.py:1204:0
#   %732 : Float(1, 1, 138, 160, strides=[22080, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%731, %pts_bbox_head.task_heads.3.height.1.weight, %pts_bbox_head.task_heads.3.height.1.bias) # /home/mark/.local/lib/python3.6/site-packages/torch/nn/modules/conv.py:396:0
#   %853 : Float(1, 64, 138, 160, strides=[1413120, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%664, %854, %855)
#   %735 : Float(1, 64, 138, 160, strides=[1413120, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%853) # /home/mark/.local/lib/python3.6/site-packages/torch/nn/functional.py:1204:0
#   %736 : Float(1, 3, 138, 160, strides=[66240, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%735, %pts_bbox_head.task_heads.3.dim.1.weight, %pts_bbox_head.task_heads.3.dim.1.bias) # /home/mark/.local/lib/python3.6/site-packages/torch/nn/modules/conv.py:396:0
#   %856 : Float(1, 64, 138, 160, strides=[1413120, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%664, %857, %858)
#   %739 : Float(1, 64, 138, 160, strides=[1413120, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%856) # /home/mark/.local/lib/python3.6/site-packages/torch/nn/functional.py:1204:0
#   %740 : Float(1, 2, 138, 160, strides=[44160, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%739, %pts_bbox_head.task_heads.3.rot.1.weight, %pts_bbox_head.task_heads.3.rot.1.bias) # /home/mark/.local/lib/python3.6/site-packages/torch/nn/modules/conv.py:396:0
#   %859 : Float(1, 64, 138, 160, strides=[1413120, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%664, %860, %861)
#   %743 : Float(1, 64, 138, 160, strides=[1413120, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%859) # /home/mark/.local/lib/python3.6/site-packages/torch/nn/functional.py:1204:0
#   %744 : Float(1, 1, 138, 160, strides=[22080, 22080, 160, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%743, %pts_bbox_head.task_heads.3.heatmap.1.weight, %pts_bbox_head.task_heads.3.heatmap.1.bias) # /home/mark/.local/lib/python3.6/site-packages/torch/nn/modules/conv.py:396:0
#   return (%668, %672, %676, %680, %684, %688, %692, %696, %700, %704, %708, %712, %716, %720, %724, %728, %732, %736, %740, %744)

# %%
import tensorrt as trt
import numpy as np
    
print('TensorRT version: ', trt.__version__)
onnx_export_pathname = 'centrpoint.onnx'

trt_logger = trt.Logger(trt.Logger.INFO)

with trt.Builder(trt_logger) as builder:
    builder.max_batch_size = 1
    
    builder_config = builder.create_builder_config()
    builder_config.reset()
    builder_config.max_workspace_size = 500 * 1024 * 1024
    builder_config.default_device_type = trt.DeviceType.GPU
    builder_config.engine_capability = trt.EngineCapability.STANDARD

    # Build TensorRT engine
    EXPLICIT_BATCH = 1 << (int)(trt.NetworkDefinitionCreationFlag.EXPLICIT_BATCH)
    with builder.create_network(EXPLICIT_BATCH) as network:
        with trt.OnnxParser(network, trt_logger) as parser:
            if not parser.parse_from_file(onnx_export_pathname):
                for error in range(parser.num_errors):
                    print(parser.get_error(error))
                raise ValueError(f'Failed to parse ONNX to TensorRT network', flush=True)

            # build engine
            network.name = 'centerpoint'
            cuda_engine = builder.build_engine(network, builder_config)

            if cuda_engine is not None:                                
                with open('centerpoint.trt', 'wb') as f:
                    f.write(cuda_engine.serialize())
                del cuda_engine                
            else:
                raise ValueError(f'Failed to build TensorRT engine')
# Out:
# TensorRT version:  8.2.3.0
# /home/mark/.local/lib/python3.6/site-packages/ipykernel_launcher.py:29: DeprecationWarning: Use build_serialized_network instead.

# %%
import tensorrt as trt
import numpy as np
import pycuda.autoinit
import pycuda.driver as cuda

cuda_engine_pathname = 'centerpoint.trt'


with open(cuda_engine_pathname, 'rb') as f:
    with trt.Runtime(trt.Logger(trt.Logger.INFO)) as runtime:
        cuda_engine =  runtime.deserialize_cuda_engine(f.read())
        
        
with cuda_engine.create_execution_context() as context:
    # Allocate GPU memory
    bindings_mem = []
    for idx in range(cuda_engine.num_bindings):
        binding_shape = context.get_binding_shape(idx)
        binding_dtype = cuda_engine.get_binding_dtype(idx)
        is_input = cuda_engine.binding_is_input(idx)
        print(f'binding {idx}: {binding_shape}, {binding_dtype}, {"input" if is_input else "output"}')
        if is_input:
            gpu_mem = cuda.to_device(np.ndarray(binding_shape, dtype= np.float32))        
        else:
            gpu_mem = cuda.mem_alloc(trt.volume(binding_shape) * binding_dtype.itemsize)        
        bindings_mem.append(gpu_mem)

        
    # Execute engine
    rc = context.execute_v2(bindings=[int(binding_mem) for binding_mem in bindings_mem])
    print('execute_v2() rc:', rc)
# Out:
# binding 0: (241, 20, 4), DataType.FLOAT, input
# binding 1: (241,), DataType.INT32, input
# binding 2: (241, 4), DataType.INT32, input
# binding 3: (1, 2, 138, 160), DataType.FLOAT, output
# binding 4: (1, 1, 138, 160), DataType.FLOAT, output
# binding 5: (1, 3, 138, 160), DataType.FLOAT, output
# binding 6: (1, 2, 138, 160), DataType.FLOAT, output
# binding 7: (1, 1, 138, 160), DataType.FLOAT, output
# binding 8: (1, 2, 138, 160), DataType.FLOAT, output
# binding 9: (1, 1, 138, 160), DataType.FLOAT, output
# binding 10: (1, 3, 138, 160), DataType.FLOAT, output
# binding 11: (1, 2, 138, 160), DataType.FLOAT, output
# binding 12: (1, 1, 138, 160), DataType.FLOAT, output
# binding 13: (1, 2, 138, 160), DataType.FLOAT, output
# binding 14: (1, 1, 138, 160), DataType.FLOAT, output
# binding 15: (1, 3, 138, 160), DataType.FLOAT, output
# binding 16: (1, 2, 138, 160), DataType.FLOAT, output
# binding 17: (1, 1, 138, 160), DataType.FLOAT, output
# binding 18: (1, 2, 138, 160), DataType.FLOAT, output
# binding 19: (1, 1, 138, 160), DataType.FLOAT, output
# binding 20: (1, 3, 138, 160), DataType.FLOAT, output
# binding 21: (1, 2, 138, 160), DataType.FLOAT, output
# binding 22: (1, 1, 138, 160), DataType.FLOAT, output
# execute_v2() rc: False

# %%
## Trace Centralpoint model
import torch


script = torch.jit.trace(model.pts_voxel_layer, pc)
script = torch.jit.trace(model, pc)


data_in = torch.randn([1, 384, 138, 160]).cuda()

script = torch.jit.trace_module(model, {'pts_bbox_head':[[data_in]]})
#script = torch.jit.script(model)
# Out:
# /home/mark/.local/lib/python3.6/site-packages/mmcv/ops/voxelize.py:75: TracerWarning: torch.tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   torch.tensor(voxel_size, dtype=torch.float),
# /home/mark/.local/lib/python3.6/site-packages/mmcv/ops/voxelize.py:76: TracerWarning: torch.tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   torch.tensor(coors_range, dtype=torch.float),
# torch.Size([1000, 4])
# /home/mark/Code/mmdetection3d/mmdet3d/models/detectors/base.py:59: TracerWarning: Converting a tensor to a Python integer might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   print(return_loss.shape)
# /home/mark/Code/mmdetection3d/mmdet3d/models/detectors/base.py:60: TracerWarning: Converting a tensor to a Python number might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if return_loss.item():
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-bdd2dbcbbfe2> in <module>
#       4
#       5 script = torch.jit.trace(model.pts_voxel_layer, pc)
# ----> 6 script = torch.jit.trace(model, pc)
#       7
#       8
#
# ~/.local/lib/python3.6/site-packages/torch/jit/_trace.py in trace(func, example_inputs, optimize, check_trace, check_inputs, check_tolerance, strict, _force_outplace, _module_class, _compilation_unit)
#     740             strict,
#     741             _force_outplace,
# --> 742             _module_class,
#     743         )
#     744
#
# ~/.local/lib/python3.6/site-packages/torch/jit/_trace.py in trace_module(mod, inputs, optimize, check_trace, check_inputs, check_tolerance, strict, _force_outplace, _module_class, _compilation_unit)
#     938                 var_lookup_fn,
#     939                 strict,
# --> 940                 _force_outplace,
#     941             )
#     942             check_trace_method = module._c._get_method(method_name)
#
# ~/.local/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     885
#     886         if torch._C._get_tracing_state():
# --> 887             result = self._slow_forward(*input, **kwargs)
#     888         else:
#     889             result = self.forward(*input, **kwargs)
#
# ~/.local/lib/python3.6/site-packages/torch/nn/modules/module.py in _slow_forward(self, *input, **kwargs)
#     858                 recording_scopes = False
#     859         try:
# --> 860             result = self.forward(*input, **kwargs)
#     861         finally:
#     862             if recording_scopes:
#
# ~/.local/lib/python3.6/site-packages/mmcv/runner/fp16_utils.py in new_func(*args, **kwargs)
#     114                                 f'method of those classes {supported_types}')
#     115             if not (hasattr(args[0], 'fp16_enabled') and args[0].fp16_enabled):
# --> 116                 return old_func(*args, **kwargs)
#     117
#     118             # get the arg spec of the decorated method
#
# ~/Code/mmdetection3d/mmdet3d/models/detectors/base.py in forward(self, return_loss, **kwargs)
#      58         """
#      59         print(return_loss.shape)
# ---> 60         if return_loss.item():
#      61             return self.forward_train(**kwargs)
#      62         else:
#
# ValueError: only one element tensors can be converted to Python scalars
